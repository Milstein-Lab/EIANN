# %% [markdown]
# # Figure 1: Multi-layer networks with biological specialization

# %% [markdown]
# <img src="diagrams/Fig1_diagrams_dynamics.png" width=1200>
