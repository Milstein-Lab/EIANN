# %% [markdown]
# # Figure 1: Multi-layer networks with biological specialization

# %% [markdown]
# <img src="diagrams/Fig1_diagrams_dynamics.png" width="1200px">

# %% [markdown]
# ```{image} diagrams/Fig1_diagrams_dynamics.png
# :alt: Diagram of EIANN network architecture
# :class: bg-primary mb-1
# :width: 200px
# :align: center
# ```
